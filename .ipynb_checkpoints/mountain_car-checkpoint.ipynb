# %%
import random
from collections import deque
import time

import numpy as np
from matplotlib import pyplot as plt
import gym
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam

# %%
class DQLSolver:
    def __init__(self, nn, max_batch_size=1024, mini_batch_size=32):
        self._nn = nn
        self._batch = deque(maxlen=max_batch_size)
        self.mini_batch_size = mini_batch_size
    
    def get_action(self, env, state, eps=.2):
        # Choose action at random
        if random.random() < eps:
            return env.action_space.sample()
        return np.argmax(self._nn.predict(np.array([state])))
        
    def remember(self, s, a, r, sn, done):
        self._batch.append((s, a, r, sn, done))
        return
    
    def exp_replay(self, gamma=.99):
        if len(self._batch) < self.mini_batch_size:
            return
        mini_batch = random.sample(self._batch, self.mini_batch_size)
        
        state_vec = []
        q_target_vec = []
        for state, action, reward, state_new, done in mini_batch:
            if done:
                q_update = reward
            else:
                q_update = reward + gamma * np.amax(self._nn.predict(np.array([state_new])))
            q_target = self._nn.predict(np.array([state]))
            q_target[0][action] = q_update
            state_vec.append(state)
            q_target_vec.append(q_target[0])
        
        state_vec = np.array(state_vec)
        q_target_vec = np.array(q_target_vec)
        self._nn.fit(state_vec, q_target_vec, verbose=0, batch_size=self.mini_batch_size//4, epochs=1)

# %%
env = gym.make('MountainCar-v0')
n_epi = 100

model = Sequential()

model.add(Dense(24, input_shape=env.observation_space.shape, activation='relu'))
model.add(Dense(24, activation='relu'))
model.add(Dense(env.action_space.n, activation='linear'))
model.compile(loss='mse', optimizer=Adam(lr=.001))
solver = DQLSolver(model)
max_positions = []

# %%
start = time.time()
eps = .5
monitor = True



for i_epi in range(n_epi):
    if not i_epi % 5:
        eps = eps/(i_epi//5 + 1)
    
    x_max = -5
    state = env.reset()
    
    for t in range(1000):

        if state[0] > x_max:
            x_max = state[0]
        if not i_epi % 1 and monitor:
            env.render()
        # Choose epsilon greedy action
        action = solver.get_action(env, state, eps=eps)
        # step
        state_new, reward, done, _ = env.step(action)
        
        reward = abs(state[0] + .5)**2 - .2 * abs(state[0] - .5)
        if done and t < 199:
            reward += 1
        solver.remember(state, action, reward, state_new, done)
        # experience replay
        solver.exp_replay()
        
        if done:
            max_positions.append(x_max)
            print(f'maximal x encountered:{x_max}')
            break
            
        state = state_new
    
env.close()
print(f'finished in {time.time() - start} seconds')
# Out:
# maximal x encountered:-0.34869562491810924
# maximal x encountered:-0.37106789210867
# maximal x encountered:-0.42595244721778286
# maximal x encountered:-0.26983485151545644
# maximal x encountered:-0.22810401697545993
# maximal x encountered:0.1925202111750557
# maximal x encountered:-0.05176803343531211
# maximal x encountered:-0.06247332279023072
# maximal x encountered:-0.17938765595956355
# maximal x encountered:-0.2971016004276829
# maximal x encountered:0.10544226803340252
# maximal x encountered:-0.1312537547482301
# maximal x encountered:0.10952916504105586
# maximal x encountered:-0.3863298282619506
# maximal x encountered:0.13653089512492486
# maximal x encountered:-0.09632068218587778
# maximal x encountered:-0.13317606224733572
# maximal x encountered:0.05529585802556836
# maximal x encountered:-0.03149342597124809
# maximal x encountered:0.007135569798749502
# maximal x encountered:0.4962940766996166
# maximal x encountered:0.388799856212751
# maximal x encountered:0.4869007238355066
# maximal x encountered:0.4869007238355066
# maximal x encountered:0.4869007238355066
# maximal x encountered:0.49433950963970924
# maximal x encountered:-0.08049309514917125
# maximal x encountered:-0.5025404696609856
# maximal x encountered:0.4668122119579742
# maximal x encountered:0.49931282713921354
# maximal x encountered:0.4762223662343483
# maximal x encountered:0.2136043896840014
# maximal x encountered:0.4708367828190304
# maximal x encountered:0.4975180406304197
# maximal x encountered:0.4869007238355066
# maximal x encountered:0.4750375815564163
# maximal x encountered:0.49698046953275143
# maximal x encountered:0.47734211789288755
# maximal x encountered:0.4869007238355066
# maximal x encountered:0.4682844894167535
# maximal x encountered:0.495673779966328
# maximal x encountered:0.47812110235227245
# maximal x encountered:0.46572118568237086
# maximal x encountered:0.4859789947546399
# maximal x encountered:0.46534780658239655
# maximal x encountered:0.46719677192041753
# maximal x encountered:0.49958147571038014
# maximal x encountered:0.49092900589212335
# maximal x encountered:0.488538706017346
# maximal x encountered:0.49740435741252836
# maximal x encountered:0.4754591703868095
# maximal x encountered:0.467605279849681
# maximal x encountered:0.4764544639056623
# maximal x encountered:0.4698827277599733
# maximal x encountered:0.4687624735160027
# maximal x encountered:0.4350869273676756
# maximal x encountered:0.46278939388946216
# maximal x encountered:0.4658124334476119
# maximal x encountered:0.46757521807251345
# maximal x encountered:0.4800138885262075
# maximal x encountered:0.4990175376041813
# maximal x encountered:0.46591048222295595
# maximal x encountered:0.4644219656307472
# maximal x encountered:0.492813652511199
# maximal x encountered:0.49042738750355724
# maximal x encountered:0.48310933712519655
# maximal x encountered:0.49425193388932287
# maximal x encountered:0.4911815703291793
# maximal x encountered:0.49906996680101845
# maximal x encountered:0.47435326645256964
# maximal x encountered:0.48947398409096554
# maximal x encountered:0.48615366585037095
# maximal x encountered:0.4603352613867442
# maximal x encountered:0.47802636506422297
# maximal x encountered:0.4981762392240099
# maximal x encountered:0.46772364580144354
# maximal x encountered:0.47658160942844563
# maximal x encountered:0.4805853634357583
# maximal x encountered:0.48250734128964473
# maximal x encountered:0.47741738584751314
# maximal x encountered:0.49534419354434867
# maximal x encountered:0.4856860569524012
# maximal x encountered:0.2279637260704349
# maximal x encountered:-0.28766988133573135
# maximal x encountered:0.14633879934542549
# maximal x encountered:-0.2862560754086155
# maximal x encountered:0.4862485363555671
# maximal x encountered:0.055113620307607164
# maximal x encountered:-0.13121800781419993
# maximal x encountered:0.480598718408922
# maximal x encountered:0.48039833256955555
# maximal x encountered:0.49809593405076114
# maximal x encountered:0.4974627118600957
# maximal x encountered:0.4965758028216435
# maximal x encountered:0.49331117560014404
# maximal x encountered:-0.34944811147742105
# maximal x encountered:-0.46142718400582333
# maximal x encountered:-0.493048680017909
# maximal x encountered:0.07656962767183391
# maximal x encountered:0.2772178900150415
# finished in 873.7801558971405 seconds

# %%
plt.plot(max_positions)

# %%
n_epi = 30
monitor = True

for i_epi in range(n_epi):
    state = env.reset()
    
    for t in range(1000):

        if state[0] > x_max:
            x_max = state[0]
        if not i_epi % 1 and monitor:
            env.render()
        # Choose epsilon greedy action
        action = solver.get_action(env, state, eps=0)
        # step
        state_new, reward, done, _ = env.step(action)
        
        reward = abs(state[0] + .5)**2 - .2 * abs(state[0] - .5)
        
        if done:
            break
            
        state = state_new
    
env.close()
print(f'finished in {time.time() - start} seconds')
# Out:
# finished in 17088.39804291725 seconds
